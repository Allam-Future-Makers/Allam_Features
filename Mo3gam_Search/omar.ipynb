# %%
# %pwd
# Out:
# '/home/omar71023/Documents/Allam_Features/Ayah_Search'

# %%
from scripts.run_search import search_quran

from scripts.run_indexing import index_quran

#index_quran()
# new ind
query = "للذين استجابوا لربهم الحسنى"
result, hits, best_hit = search_quran(query)
print(result)
print("----------")
print(hits)
print("----------")
print(best_hit)
#for hit in hits:
#    print(hit["_source"]["Ayah"])
# Out:
# Ayah: لِلَّذِينَ اسْتَجَابُوا لِرَبِّهِمُ الْحُسْنَىٰ ۚ وَالَّذِينَ لَمْ يَسْتَجِيبُوا لَهُ لَوْ أَنَّ لَهُم مَّا فِي الْأَرْضِ جَمِيعًا وَمِثْلَهُ مَعَهُ لَافْتَدَوْا بِهِ ۚ أُولَٰئِكَ لَهُمْ سُوءُ الْحِسَابِ وَمَأْوَاهُمْ جَهَنَّمُ ۖ وَبِئْسَ الْمِهَادُ
# Tafseer Mokhtasar: للمؤمنين الذين أجابوا ربهم لما دعاهم لتوحيده وطاعته المثوبة الحسنى وهي الجنة، والكفار الذين لم يجيبوا دعوته إلى توحيده وطاعته لو اتفق أن لهم ما في الأرض من أنواع المال، ولهم مثله مضافًا إليه؛ لبذلوا كل ذلك فداءً لأنفسهم من العذاب، أولئك الذين لم يجيبوا دعوته يحاسبون على سيئاتهم كلها، ومسكنهم الذي يأوون إليه جهنم، وساء فراشهم ومستقرهم الذي هو النار.
# Telawa: https://www.everyayah.com/data/Yasser_Ad-Dussary_128kbps/013018.mp3
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(template="""
you will given arabic context, and I need you to get the answer to the query given to you.
here is the context: {context}
                        
and here is the query: {query}

""")
from langchain_google_genai import ChatGoogleGenerativeAI
gemini_llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", api_key="AIzaSyA0WgVJxLelaY3fvIhq4XK8Av9udDfJ9rI")

chain = prompt | gemini_llm
chain.invoke({"context":str(l[:3]),"query":"أعطنى الآية الثانية والمقطع الصوتى لها"}).content
# Out:
# '## الآية الثانية والمقطع الصوتى لها:\n\n**الآية:** وَالَّذِينَ اسْتَجَابُوا لِرَبِّهِمْ وَأَقَامُوا الصَّلَاةَ وَأَمْرُهُمْ شُورَىٰ بَيْنَهُمْ وَمِمَّا رَزَقْنَاهُمْ يُنفِقُونَ\n\n**المقطع الصوتى:** https://www.everyayah.com/data/Yasser_Ad-Dussary_128kbps/042038.mp3 \n'

# %%
l = []
for hit in hits:
    l.append(hit['_source'])

# %%
url = 'https://www.everyayah.com/data/Yasser_Ad-Dussary_128kbps/042038.mp3'
import requests
res  = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.content
# Out:
# b'ID3\x03\x00\x00\x00\x00\x02BTIT2\x00\x00\x00\x0e\x00\x00\x00042-Ash-ShuraTRCK\x00\x00\x00\x02\x00\x00\x001COMM\x00\x00\x00&\x00\x00\x00XXXID3v1 Comment\x00www.quranicaudio.comTCON\x00\x00\x00\x05\x00\x00\x00(12)TPE1\x00\x00\x00\x12\x00\x00\x00Yasser_Ad-DussaryTALB\x00\x00\x00,\x00\x00\x00(C) VerseByVerseQuran.com Yasser_Ad-DussaryCOMM\x00\x00\x00A\x00\x00\x00\x00\x00\x00\x00MP3s from download.quranicaudio.com/quran/yasser_ad-dussary/`\xc1\x80\x04\xe0RX\xe1\xef{j!\xa3+,,\xe5IS\rGc\xc7\xb1\xed\xa8\xa2\x8b\xecx\xc4\x19!$\x9aH\xa9\x93\xf90F\xd0\xc4\xe2\t\xb5\xbdF\x91\x89\x05\xcd\x88QHo\x93\xac*M\xa2\x82y\xacy0s$* \x01"F \x18i\xb3P&\x88\x14;q\xa44\x85\xea\xc2Y\xcdX\xae\x82\xfbp\xad\xfd>\xff\xd7\xffT\x9f^3]`\xd1E\x11
# ...

# %%
from playsound import playsound
file_path = "omar.mp3"
with open(file_path, 'wb') as file:
    file.write(res.content)

# Play the MP3 file
playsound(file_path)
